# %%
arr1 = np.random.randint(1, 50, size=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 arr1 = np.random.randint(1, 50, size=10)
#
# NameError: name 'np' is not defined

# %%
pip install numpy
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.0 kB ? eta -:--:--
#      -------------------------------------- 61.0/61.0 kB 806.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.8 MB 1.3 MB/s eta 0:00:13
#    ---------------------------------------- 0.1/15.8 MB 907.3 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/15.8 MB 1.1 MB/s eta 0:00:15
#     --------------------------------------- 0.2/15.8 MB 1.2 MB/s eta 0:00:13
#    - -------------------------------------- 0.4/15.8 MB 1.9 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/15.8 MB 1.8 MB/s eta 0:00:09
#    - -------------------------------------- 0.6/15.8 MB 1.9 MB/s eta 0:00:09
#    - -------------------------------------- 0.7/15.8 MB 1.9 MB/s eta 0:00:08
# ...

# %%
import numpy as np

# %%
arr1 = np.random.randint(1, 50, size=10)

arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 arr1 = np.random.randint(1, 50, size=10)
# ----> 3 arr
#
# NameError: name 'arr' is not defined

# %%
arr1

# %%
arr1 = np.random.randint(1, 50, size=10)

arr1

# %%
arr1 = np.random.randint(1, 50, size=10)

arr1
# Out:
# array([19, 17, 23, 37, 44, 20, 22, 29,  2, 24])

# %%
np.mean(arr1)
# Out:
# 23.7

# %%
a1 = np.random.randint(1, 50, size=(3,3)
# Out:
#   Cell In[7], line 1
#     a1 = np.random.randint(1, 50, size=(3,3)
#                                             ^
# SyntaxError: incomplete input

# %%
a1 = np.random.randint(1, 50, size=(3,3))

# %%
a1
# Out:
# array([[ 7, 43, 46],
#        [19, 24, 32],
#        [21, 43, 46]])

# %%
a2 = np.random.randint(1, 50, size=(3,3))
a2
# Out:
# array([[28, 13, 39],
#        [48, 25, 26],
#        [32,  4, 18]])

# %%
a=np.add(a1,a2)
a
# Out:
# array([[35, 56, 85],
#        [67, 49, 58],
#        [53, 47, 64]])

# %%
np.mean(a)
# Out:
# 57.111111111111114

# %%
arr2 = np.random.randint(1, 100, size=20 )
arr2
# Out:
# array([60, 25, 94, 65, 24, 75, 59, 16, 89, 50, 55, 74, 62, 62, 16, 37, 53,
#        99, 59, 52])

# %%
bigger = arr2[arr2>50]

# %%
bigger
# Out:
# array([60, 94, 65, 75, 59, 89, 55, 74, 62, 62, 53, 99, 59, 52])

# %%
arr3 = [60, 94, 65, 75, 59, 89, 55, 74, 62, 62]

# %%
np.random.shuffle(arr3)

# %%
arr3
# Out:
# [75, 62, 89, 59, 55, 60, 74, 65, 94, 62]

# %%
arr3[np.random.randint(1,10)]
# Out:
# 60
